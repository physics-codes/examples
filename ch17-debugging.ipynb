# %%
def mean(nums):
    bot = len(nums)
    it = 0
    top = 0
    while it < len(nums):
        top += nums[it]
    return float(top) / float(bot)

if __name__ == "__main__":
    a_list = [1, 2, 3, 4, 5, 6, 10, "one hundred"]
    mean(a_list)

# %%
def mean(nums):
    bot = len(nums)
    it = 0
    top = 0
    print("Still Running at line 5") <1>
    while it < len(nums):
        top += nums[it]
        print(top) <2>
    return float(top) / float(bot)

if __name__ == "__main__":
    a_list = [1, 2, 3, 4, 5, 6, 10, "one hundred"]
    mean(a_list)

# %%
def mean(nums):
    top = sum(nums) <1>
    bot = len(nums)
    return float(top) / float(bot)

if __name__ == "__main__":
    a_list = [1, 2, 3, 4, 5, 6, 10, "one hundred"]
    mean(a_list)

# %%
Traceback (most recent call last):
  File "a_list_mean.py", line 9, in <module>
    mean(a_list)
  File "a_list_mean.py", line 2, in mean
    top = sum(nums)
TypeError: unsupported operand type(s) for +: 'int' and 'str' <1>

# %%
import pdb <1>

def mean(nums):
    top = sum(nums)
    bot = len(nums)
    return float(top) / float(bot)

if __name__ == "__main__":
    a_list = [1, 2, 3, 4, 5, 6, 10, "one hundred"]
    mean(a_list)

# %%
import pdb

def mean(nums):
    top = sum(nums)
    bot = len(nums)
    return float(top) / float(bot)

if __name__ == "__main__":
    pdb.set_trace() <1>
    a_list = [1, 2, 3, 4, 5, 6, 10, "one hundred"]
    mean(a_list)

# %%
> /filespace/users/h/hopper/bugs/a_list_mean.py(10)<module>()
-> a_list = [1, 2, 3, 4, 5, 6, 10, "one hundred"]
(pdb) <1>

# %%
(Pdb) s


(Pdb) a_list

# %%
> /filespace/users/h/hopper/bugs/
a_list_mean.py(10)<module>()
-> mean(a_list)

[1, 2, 3, 4, 5, 6, 10, 'one hundred']

# %%
(Pdb) a_list[-1] = 100
(Pdb) a_list

# %%
[1, 2, 3, 4, 5, 6, 10, 100]

# %%
(Pdb) sum(a_list)

# %%
131

# %%
def mean(nums):
    top = sum(nums)
    bot = len(nums)
    return float(top) / float(bot)

if __name__ == "__main__":
    a_list = [1, 2, 3, 4, 5, 6, 10, 100]
    result = mean(a_list)
    print result

# %%
In [1]: import pstats

In [2]: p = pstats.Stats('output.prof')

In [3]: p.print_stats()
Mon Dec  8 19:43:12 2014    output.prof

         5 function calls in 0.000 seconds <1>

   Random listing order was used

   ncalls  tottime  percall  cumtime  percall filename:lineno(function) <2>
        1    0.000    0.000    0.000    0.000 fixed_mean.py:1(<module>)
        1    0.000    0.000    0.000    0.000 {sum}
        1    0.000    0.000    0.000    0.000 fixed_mean.py:1(mean)
        1    0.000    0.000    0.000    0.000 {method 'disable' of ...
        1    0.000    0.000    0.000    0.000 {len}
