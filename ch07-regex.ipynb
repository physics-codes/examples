# %%
In [1]: import re <1>

In [2]: re.match("20[01][0-9].*[0-9][0-9].*[0-9][0-9]", '2015-12-16') <2>
Out[2]: <_sre.SRE_Match object; span=(0, 10), match='2015-12-16'>

In [3]: m = re.match("20[01][0-9].*[0-9][0-9].*[0-9][0-9]", '2015-12-16') <3>

In [4]: m.pos <4>
Out[4]: 0

In [5]: m.groups() <5>
Out[5]: ()

In [6]: m = re.match("20[01][0-9].*[0-9][0-9].*[0-9][0-9]", 'not-a-date') <6>

In [7]: m is None <7>
Out[7]: True

# %%
In [8]: re_date = re.compile("(20[01][0-9]).*([0-9][0-9]).*([0-9][0-9])") <1>

In [9]: re_date.match('2014-28-01') <2>
Out[9]: <_sre.SRE_Match object; span=(0, 10), match='2014-28-01'>

In [10]: m = re_date.match('2014-28-01') <3>

In [11]: m.groups() <4>
Out[11]: ('2014', '28', '01')
